# %%
def greet():
    print("Hello There")

# %%
greet()
# Out:
# Hello There

# %%
def greet(name):
    print("Hello", name)

greet("Sky")
greet("Cloudy")
# Out:
# Hello Sky
# Hello Cloudy

# %%
def add(a,b):
    return a + b

result = add(4,8)
print(result)
# Out:
# 12

# %%
def greet(name = "Guest"):
    print("Hello",name)

greet()
greet("Sky")
greet("Snow")
# Out:
# Hello Guest
# Hello Sky
# Hello Snow

# %%
def calculate(a,b):
    return a + b, a - b
sum_value,diff_value = calculate(20,4)
print(sum_value,diff_value)
# Out:
# 24 16

# %%
print(diff_value)
print(sum_value)
# Out:
# 16
# 24

# %%
#local vs global

x = 20 #Global

def test():
    x = 5 #local
    print(x) 

test()
print(x)
# Out:
# 5
# 20

# %%
def find(a,b):
    if a % b == 0:
        return("Even")
    else:
        print("Odd")
find(2,21)
# Out:
# Odd

# %%
def check_even_odd(a):
    if a % 2 == 0:
        print("Even")
    else:
        print("Odd")

check_even_odd(41)
# Out:
# Odd

# %%
def check_even_odd(a):
    if a % 2 == 0:
        return "Even"
    else:
        return "Odd"
result = check_even_odd(41)
print(result)
# Out:
# Odd
