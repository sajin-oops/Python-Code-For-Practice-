# %%
words = ["data","engineer","python"]
word_length = {w:len(w) for w in words}

# %%
word_length
# Out:
# {'data': 4, 'engineer': 8, 'python': 6}

# %%
columns = ["id","name","created_at"]
dtypes = ["int",'str','datetime']
schema = {col: dtype for col,dtype in zip(columns,dtypes)}

# %%
schema
# Out:
# {'id': 'int', 'name': 'str', 'created_at': 'datetime'}

# %%
prices = {'apple':100,'banana':40,'cherry':300}
expensive = {k : v for k,v in prices.items() if v > 50}

# %%
expensive
# Out:
# {'apple': 100, 'cherry': 300}
