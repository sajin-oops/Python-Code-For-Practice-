# %%
name = 'Snow'

# %%
name
# Out:
# 'Snow'

# %%
course = 'Python'

# %%
course
# Out:
# 'Python'

# %%
text = "Dummy Baba"

# %%
print(text)
print(text.upper())
print(text.lower())
# Out:
# Dummy Baba
# DUMMY BABA
# dummy baba

# %%
name = "data engineer"

# %%
name
# Out:
# 'data engineer'

# %%
print(name.title())
print(name.capitalize())
# Out:
# Data Engineer
# Data engineer

# %%
msg = "       He llo    "

# %%
print(msg)
print(msg.lstrip())
print(msg.rstrip())
# Out:
#        He llo
# He llo
#        He llo

# %%
print(msg)
# Out:
#        He llo

# %%
print(len(msg))
print(len(msg.lstrip()))
print(len(msg.rstrip()))
# Out:
# 17
# 10
# 13

# %%
text = "I Love Macbook Pro"
print(text)
print(text.replace("Pro","Air")) #Temporarily replace the value :)
print(text)
# Out:
# I Love Macbook Pro
# I Love Macbook Air
# I Love Macbook Pro

# %%
text = "Apple company is coming to chennai"
print(text)
print(text.find("coming"))
print(text.find("ipad"))
# Out:
# Apple company is coming to chennai
# 17
# -1

# %%
print(text.index("company"))
# Out:
# 6

# %%
text = "Apple"

# %%
print(text.count("p"))
# Out:
# 2

# %%
print(text.startswith("A"))
print(text.endswith("A"))
print(text.endswith("e"))
# Out:
# True
# False
# True

# %%
sentence = "Learning python is super fun"
words = sentence.split()

# %%
words
# Out:
# ['Learning', 'python', 'is', 'super', 'fun']

# %%
joined = " ".join(sentence)
joined
# Out:
# 'L e a r n i n g   p y t h o n   i s   s u p e r   f u n'

# %%
joined = "-".join(words)
joined
# Out:
# 'Learning-python-is-super-fun'

# %%
joined = "-".join(sentence)
joined
# Out:
# 'L-e-a-r-n-i-n-g- -p-y-t-h-o-n- -i-s- -s-u-p-e-r- -f-u-n'

# %%
print("Python".isalpha())
print("123".isdigit())
# print(123.isdigit())
# Out:
# True
# True

# %%
name = "Snow"
age = "2 Months"
print(name,"is "+ age)
# Out:
# Snow is 2 Months

# %%
print(f"{name} is {age}")
# Out:
# Snow is 2 Months
