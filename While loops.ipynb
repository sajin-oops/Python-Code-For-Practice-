# %%
count = 1
while count <= 5:
    print(f"Iteration number: {count}")
    count += 1
print("Loop finished!")
# Out:
# Iteration number: 1
# Iteration number: 2
# Iteration number: 3
# Iteration number: 4
# Iteration number: 5
# Loop finished!

# %%
secret_password =  "snakebabu"
user_guess = ""
while user_guess != secret_password:
    user_guess = input("Enter the password to stop: ")

    if user_guess == secret_password:
        print("Access Granted!")
    else:
        print("Wrong Try Again.!")
# Out:
# Enter the password to stop:  snake
# Wrong Try Again.!
# Enter the password to stop:  babu
# Wrong Try Again.!
# Enter the password to stop:  snakebabu
# Access Granted!

# %%
num = 8
while num < 100:
    if num % 7 == 0:
        print(F"Found it! {num} is the first multiple of 7 after 8.")
        break #This will stop the loop immediately
    num += 1
# Out:
# Found it! 14 is the first multiple of 7 after 8.

# %%
while True:
    action = input("Type 'exit' to quit: ")
    if action == 'exit':
        break
# Out:
# Type 'exit' to quit:  EXIT
# Type 'exit' to quit:  exit
