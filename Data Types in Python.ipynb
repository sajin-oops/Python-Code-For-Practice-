# %%
x = "Hello"
x
# Out:
# 'Hello'

# %%
type(x)
# Out:
# str

# %%
age = 23
type(age)
# Out:
# int

# %%
b = 23.0
type(b)
# Out:
# float

# %%
im = "Mr.True" # Have something
bool(im)
# Out:
# True

# %%
do = "" # Empty
bool(do)
# Out:
# False

# %%
pi = 3.14

# %%
print(pi)
print(type(pi))
# Out:
# 3.14
# <class 'float'>

# %%
college  = "Madras christian college"
college
# Out:
# 'Madras christian college'

# %%
print(college)
# Out:
# Madras christian college
