# %%
try:
    num = int(input("Enter a number: "))
    print(10 / num)
except ZeroDivisionError:
    print("You cannot divide by zero.")
except ValueError:
    print("Please enter a vlaid number")
finally:
    print("Execution completed")
# Out:
# Enter a number:  0
# You cannot divide by zero.
# Execution completed

# %%
try:
    num = int(input("Enter a number: "))
    print(10 / num)
except ZeroDivisionError:
    print("You cannot divide by zero.")
except ValueError:
    print("Please enter a vlaid number")
finally:
    print("Execution completed")
# Out:
# Enter a number:  5
# 2.0
# Execution completed

# %%
try:
    num = int(input("Enter a number: "))
    print(10 / num)
except ZeroDivisionError:
    print("You cannot divide by zero.")
except ValueError:
    print("Please enter a vlaid number")
finally:
    print("Execution completed")
# Out:
# Enter a number:  ll
# Please enter a vlaid number
# Execution completed

# %%
import pandas as pd
try:
    df = pd.read_csv("Test.csv")
    print(df.head())
except FileNotFoundError:
    print("File not found. check the file path.")
except Exception as e:
    print("Something went wrong:",e)
# Out:
# File not found. check the file path.

# %%
import os 
os.getcwd()
# Out:
# '/Users/sajin/Python Learning '
