# %%
friends = ["Snow","Milo","Sajin","Cloudy"]
for name in friends:
    print("Hello " + name)
# Out:
# Hello Snow
# Hello Milo
# Hello Sajin
# Hello Cloudy

# %%
for i in range(5):
    print("Loop number:", i)
# Out:
# Loop number: 0
# Loop number: 1
# Loop number: 2
# Loop number: 3
# Loop number: 4

# %%
prices = [10,20,30,2,18]
total = 0
for price in prices:
    total = total + price
    
print("The total bill is: ", total)
# Out:
# The total bill is:  80

# %%
scores = [45,99,88,64,32,11]
for s in scores:
    if s >=60:
        print("Passing score found:",s)
# Out:
# Passing score found: 99
# Passing score found: 88
# Passing score found: 64

# %%
word = "BlueBerrryBlackBerry"
for letter in word:
    print(letter.upper())
# Out:
# B
# L
# U
# E
# B
# E
# R
# R
# R
# Y
# B
# L
# A
# C
# K
# B
# E
# R
# R
# Y
