# %%
age = 23

if age >= 20:
    print("You are eligible to dance")
# Out:
# You are eligible to dance

# %%
age = 15
if age >= 18:
    print("You can vote")
else:
    print("You better grow man!")
# Out:
# You better grow man!

# %%
total = 0

if total >= 450:
    print("Grade A")
elif total >= 350:
    print("Grade B")
elif total >= 300:
    print("Grade C")
elif total >=250:
    print("Grade D")
else:
    print("Your Chapter Over!")
# Out:
# Your Chapter Over!

# %%
age = 3
id_card = True
                                #Hahahaha
if age >= 18 and id_card:
    print("Please come in")
else:
    print("Now Get Out :)")
# Out:
# Now Get Out :)

# %%
username = "admin123"

if username  == "admin":
    print("Welcome admin")
else:
    print("Access denied")
# Out:
# Access denied

# %%
# goal = "fat loss"
goal = input(str("Choose your options:[fat loss,muscle gain]"))
if goal == "fat loss":
    print("Do cardio + calorie deficit")
elif goal == "muscle gain":
    
    print("Lift weights + calorie surplus")
else:
    print("Maintain current routine")
# Out:
# Choose your options:[fat loss,muscle gain] fat loss
# Do cardio + calorie deficit

# %%
print("Choose Your Goal:")
print("1.Fat loss")
print("2.Muscle gain")

choice = input("Enter 1 or 2:")
if choice == "1":
    print("Do cardio + calorie deficit")
elif choice == "2":
    print("Lift weights + calorie surplus")
else:
    print("Maintain current routine")
# Out:
# Choose Your Goal:
# 1.Fat loss
# 2.Muscle gain
# Enter 1 or 2: 1
# Do cardio + calorie deficit
