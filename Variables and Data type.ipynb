# %%
# Variables

a = 'Sajin'

# %%
a
# Out:
# 'Sajin'

# %%
b = 'Nijas'

# %%
b
# Out:
# 'Nijas'

# %%
print(type(a))
# Out:
# <class 'str'>

# %%
c = 1

# %%
print(c)
print(type(c))
# Out:
# 1
# <class 'int'>

# %%
d = 14.3
print(d)
print(type(d))
# Out:
# 14.3
# <class 'float'>

# %%
a = True
b = False

# %%
a
# Out:
# True

# %%
b
# Out:
# False

# %%
a = "Hello There"
print(a)
print(type(a))
print(bool(a))
# Out:
# Hello There
# <class 'str'>
# True

# %%
c = ""
print(c)
print(bool(c))  # The variable c is empty without values
# Out:
# False

# %%
a  = 10
b = -5
c = a + b
result = c
print(c) # haha
# Out:
# 5
