# %%
class MyError(Exception):
    pass

raise MyError("Something went wrong")
# Out:
# ---------------------------------------------------------------------------
# MyError                                   Traceback (most recent call last)
# Cell In[1], line 4
#       1 class MyError(Exception):
#       2     pass
# ----> 4 raise MyError("Something went wrong")
#
# MyError: Something went wrong

# %%
class ValidationError(Exception):
    def __init__(self,field,message):
        self.field = field
        super().__init__(f"Validation failed on '{field}': {message}")

raise ValidationError("email", "Invalid format")
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[4], line 6
#       3         self.field = field
#       4         super().__init__(f"Validation failed on '{field}': {message}")
# ----> 6 raise ValidationError("email", "Invalid format")
#
# ValidationError: Validation failed on 'email': Invalid format
